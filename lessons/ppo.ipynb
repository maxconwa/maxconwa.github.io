# %% [raw]
# ---
# title: "Proximal policy optimization (PPO)"
# summary: "Optimising the policy directly, with a trust region that keeps each update from destroying it."
# prereqs: [deep-q-learning]
# track: Reinforcement learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Proximal policy optimization (PPO)
#
# The lesson goes here.
