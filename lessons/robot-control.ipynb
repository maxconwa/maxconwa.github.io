# %% [raw]
# ---
# title: "Robot control"
# summary: "Joint-space and task-space control on a real arm, before any of it is learned."
# prereqs: []
# track: Humanoid autonomy
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Robot control
#
# The lesson goes here.
