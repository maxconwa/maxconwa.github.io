# %% [raw]
# ---
# title: "Gradient descent"
# summary: "Solving the same fit iteratively instead of in closed form, and what the step size costs you."
# prereqs: [linear-regression]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Gradient descent
#
# The lesson goes here.
