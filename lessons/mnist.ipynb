# %% [raw]
# ---
# title: "MNIST"
# summary: "The first real dataset: a multilayer perceptron trained end to end on handwritten digits."
# prereqs: [logistic-regression, adam]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## MNIST
#
# The lesson goes here.
