# %% [raw]
# ---
# title: "Learning a whole-body humanoid policy"
# summary: "One policy for locomotion and manipulation together, where the two can no longer be separated."
# prereqs: [learning-humanoid-balance, learning-humanoid-end-effector-control, dreamerv3, transformer]
# track: Humanoid autonomy
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Learning a whole-body humanoid policy
#
# The lesson goes here.
