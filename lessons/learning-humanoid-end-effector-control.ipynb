# %% [raw]
# ---
# title: "Learning humanoid end-effector control"
# summary: "Precise reaching and manipulation with a humanoid arm, learned rather than solved analytically."
# prereqs: [robot-control, sac]
# track: Humanoid autonomy
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Learning humanoid end-effector control
#
# The lesson goes here.
