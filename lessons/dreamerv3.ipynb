# %% [raw]
# ---
# title: "DreamerV3"
# summary: "Learning a world model and planning inside it, rather than learning only from real experience."
# prereqs: [sac, rnn]
# track: Reinforcement learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## DreamerV3
#
# The lesson goes here.
