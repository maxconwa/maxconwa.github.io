# %% [raw]
# ---
# title: "Transformers"
# summary: "Replacing recurrence with attention, and the block that the rest of the field is built on."
# prereqs: [rnn]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Transformers
#
# The lesson goes here.
