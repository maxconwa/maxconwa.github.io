# %% [raw]
# ---
# title: "Logistic regression"
# summary: "Moving from predicting a number to predicting a probability, and the loss that makes it work."
# prereqs: [gradient-descent]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Logistic regression
#
# The lesson goes here.
