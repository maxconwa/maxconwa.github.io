# %% [raw]
# ---
# title: "Learning humanoid balance"
# summary: "Staying upright as a learned policy: contacts, disturbances, and what the reward has to say."
# prereqs: [robot-control, ppo]
# track: Humanoid autonomy
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Learning humanoid balance
#
# The lesson goes here.
