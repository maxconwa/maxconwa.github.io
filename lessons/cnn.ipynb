# %% [raw]
# ---
# title: "Convolutional networks"
# summary: "Weight sharing and locality, and why they beat a dense layer on anything shaped like an image."
# prereqs: [mnist]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Convolutional networks
#
# The lesson goes here.
