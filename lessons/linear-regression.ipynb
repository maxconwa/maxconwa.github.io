# %% [raw]
# ---
# title: "Linear regression"
# summary: "Fitting a line by least squares, and what the normal equations tell you about the problem."
# prereqs: []
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Linear regression
#
# The lesson goes here.
