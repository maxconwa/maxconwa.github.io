# %% [raw]
# ---
# title: "JAX"
# summary: "The same ideas as composable function transformations: jit, grad and vmap over pure functions."
# prereqs: [logistic-regression]
# track: Supervised learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## JAX
#
# The lesson goes here.
