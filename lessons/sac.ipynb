# %% [raw]
# ---
# title: "Soft actor-critic (SAC)"
# summary: "Off-policy actor-critic with an entropy bonus: the workhorse for continuous control."
# prereqs: [deep-q-learning, ppo]
# track: Reinforcement learning
# runnable: false
# ---

# %% [markdown]
# *Not written yet.*
#
# ## Soft actor-critic (SAC)
#
# The lesson goes here.
